# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('VoltageRecording-VGLUTDTRM1_23_waterintake_T1_041022-000_Cycle00001_VoltageRecording_001.csv')

# %%
df=df.set_index('Time(ms)')

# %%
df.index=df.index/1000
df.index=df.index/60
df
# Out:
#             Input 0   Input 1
# Time(ms)
# 0.000000  -0.007019 -0.006104
# 0.000017  -0.006104 -0.005798
# 0.000033  -0.004883 -0.005798
# 0.000050  -0.006714 -0.005798
# 0.000067  -0.006409 -0.005798
# ...             ...       ...
# 24.489600 -0.006409 -0.006714
# 24.489617 -0.006104 -0.006104
# 24.489633 -0.007019 -0.005798
# 24.489650 -0.005493 -0.006714
# 24.489667 -0.007019 -0.005493
#
# [1469381 rows x 2 columns]

# %%
df.plot(y=[" Input 0", " Input 1"], figsize=(500, 8))
# Out:
# <AxesSubplot:xlabel='Time(ms)'>

# %%
df_vglutm1=pd.read_csv('VGLUTM1_23_waterintake_T1_041022-004_Cycle00001_VoltageRecording_001.csv')
df_vglutm1=df_vglutm1.set_index('Time(ms)')
df_vglutm1.index=df_vglutm1.index/1000
df_vglutm1.index=df_vglutm1.index/60
# Out:
#             Input 0   Input 1
# Time(ms)
# 0.000000  -0.005493 -0.006714
# 0.000017  -0.007935 -0.006714
# 0.000033  -0.005798 -0.006409
# 0.000050  -0.007935 -0.007935
# 0.000067  -0.008240 -0.007935
# ...             ...       ...
# 40.097750 -0.005493 -0.006714
# 40.097767 -0.006104 -0.006714
# 40.097783 -0.007935 -0.007019
# 40.097800 -0.006714 -0.006714
# 40.097817 -0.006714 -0.007019
#
# [2405870 rows x 2 columns]

# %%
df_vglutm1.plot(y=[" Input 0", " Input 1"], figsize=(40, 8))
# Out:
# <AxesSubplot:xlabel='Time(ms)'>
